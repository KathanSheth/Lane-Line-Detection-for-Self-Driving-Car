# %%
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import pyparsing
# %matplotlib inline

# %%
img = mpimg.imread('challenge_photos/frame0.jpg')
#gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
print (img.shape)
print (img[5,1:25])
darker_image = np.asarray( np.dot(img, 0.5), dtype=int)
print (darker_image.shape)
print (darker_image[5,1:25])
# Out:
# (720, 1280, 3)
# [[115 153 190]
#  [114 152 189]
#  [112 152 188]
#  [110 150 186]
#  [108 151 186]
#  [108 151 186]
#  [108 150 188]
#  [110 149 188]
#  [112 151 190]
#  [112 151 190]
#  [109 151 189]
#  [111 153 191]
#  [111 155 192]
#  [110 154 191]
#  [106 152 188]
#  [106 150 187]
#  [109 153 190]
#  [108 152 189]
#  [111 155 192]
#  [107 151 188]
#  [110 154 191]
#  [109 151 189]
#  [111 153 191]
#  [111 153 191]]
# (720, 1280, 3)
# [[57 76 95]
#  [57 76 94]
#  [56 76 94]
#  [55 75 93]
#  [54 75 93]
#  [54 75 93]
#  [54 75 94]
#  [55 74 94]
#  [56 75 95]
#  [56 75 95]
#  [54 75 94]
#  [55 76 95]
#  [55 77 96]
#  [55 77 95]
#  [53 76 94]
#  [53 75 93]
#  [54 76 95]
#  [54 76 94]
#  [55 77 96]
#  [53 75 94]
#  [55 77 95]
#  [54 75 94]
#  [55 76 95]
#  [55 76 95]]

# %%
plt.imshow(darker_image)
